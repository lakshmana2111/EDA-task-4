# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("/content/shopify_stock.csv")

# %%
df.head()
# Out:
#                         date   open   high    low  close  adj_close     volume
# 0  2015-05-21 00:00:00-04:00  2.800  2.874  2.411  2.568      2.568  123039000
# 1  2015-05-22 00:00:00-04:00  2.607  3.110  2.600  2.831      2.831   28412000
# 2  2015-05-26 00:00:00-04:00  2.980  3.034  2.908  2.965      2.965    8202000
# 3  2015-05-27 00:00:00-04:00  3.067  3.081  2.700  2.750      2.750    7976000
# 4  2015-05-28 00:00:00-04:00  2.755  2.774  2.648  2.745      2.745    4000000

# %%
df.tail()
# Out:
#                            date       open       high        low      close  \
# 2464  2025-03-10 00:00:00-04:00  96.070000  96.186996  91.690002  92.750000
# 2465  2025-03-11 00:00:00-04:00  92.750000  95.109001  91.150002  92.949997
# 2466  2025-03-12 00:00:00-04:00  96.669998  99.135002  95.290001  96.529999
# 2467  2025-03-13 00:00:00-04:00  95.169998  95.529999  89.099998  90.589996
# 2468  2025-03-14 00:00:00-04:00  94.610001  95.830002  93.059998  94.849998
#
#       adj_close    volume
# 2464  92.750000  16385300
# 2465  92.949997  12127100
# 2466  96.529999   8531900
# 2467  90.589996  11076400
# 2468  94.849998   7060700

# %%
df.shape
# Out:
# (2469, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2469 entries, 0 to 2468
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       2469 non-null   object
#  1   open       2469 non-null   float64
#  2   high       2469 non-null   float64
#  3   low        2469 non-null   float64
#  4   close      2469 non-null   float64
#  5   adj_close  2469 non-null   float64
#  6   volume     2469 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 135.2+ KB

# %%
df.describe()
# Out:
#               open         high          low        close    adj_close  \
# count  2469.000000  2469.000000  2469.000000  2469.000000  2469.000000
# mean     48.464345    49.505495    47.347795    48.456613    48.456613
# std      43.633916    44.470235    42.642546    43.573362    43.573362
# min       1.939000     1.985000     1.848000     1.933000     1.933000
# 25%      10.479000    10.635000    10.275000    10.450000    10.450000
# 50%      35.640999    36.879002    34.655998    35.874001    35.874001
# 75%      76.080002    77.169998    74.589996    75.800003    75.800003
# max     171.800003   176.291794   168.509506   169.059998   169.059998
#
#              volume
# count  2.469000e+03
# mean   1.657049e+07
# std    1.436909e+07
# min    1.039000e+06
# 25%    8.098000e+06
# 50%    1.275860e+07
# 75%    2.060200e+07
# max    2.089590e+08

# %%
df["date"]=pd.to_datetime(df["date"],utc=True)
df['date'].dtype
df
# Out:
#                           date       open       high        low      close  \
# 0    2015-05-21 04:00:00+00:00   2.800000   2.874000   2.411000   2.568000
# 1    2015-05-22 04:00:00+00:00   2.607000   3.110000   2.600000   2.831000
# 2    2015-05-26 04:00:00+00:00   2.980000   3.034000   2.908000   2.965000
# 3    2015-05-27 04:00:00+00:00   3.067000   3.081000   2.700000   2.750000
# 4    2015-05-28 04:00:00+00:00   2.755000   2.774000   2.648000   2.745000
# ...                        ...        ...        ...        ...        ...
# 2464 2025-03-10 04:00:00+00:00  96.070000  96.186996  91.690002  92.750000
# 2465 2025-03-11 04:00:00+00:00  92.750000  95.109001  91.150002  92.949997
# 2466 2025-03-12 04:00:00+00:00  96.669998  99.135002  95.290001  96.529999
# 2467 2025-03-13 04:00:00+00:00  95.169998  95.529999  89.099998  90.589996
# 2468 2025-03-14 04:00:00+00:00  94.610001  95.830002  93.059998  94.849998
#
#       adj_close     volume
# 0      2.568000  123039000
# 1      2.831000   28412000
# 2      2.965000    8202000
# 3      2.750000    7976000
# 4      2.745000    4000000
# ...         ...        ...
# 2464  92.750000   16385300
# 2465  92.949997   12127100
# 2466  96.529999    8531900
# 2467  90.589996   11076400
# 2468  94.849998    7060700
#
# [2469 rows x 7 columns]

# %%
df=df.sort_values("date")

# %%
plt.figure(figsize=(16,8))
plt.plot(df.index, df["open"], label="open")
plt.plot(df.index, df["high"], label="high")
plt.plot(df.index, df["low"], label="low")
plt.plot(df.index, df["close"], label="close")

plt.title("Shopify Stock Price")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.plot(df.index, df["volume"], label="volume")

plt.title("Shopify Stock Volume")
plt.xlabel("Date")
plt.ylabel("Volume")
# Out:
# Text(0, 0.5, 'Volume')

# %%
df["MA20"]=df["close"].rolling(window=20).mean()
df["MA50"]=df["close"].rolling(window=50).mean()

# %%
plt.figure(figsize=(12,6))
plt.plot(df.index, df["close"], label="Daily Close")
plt.title("Shopify stock closing price trend")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=())

# %%
df["Daily_Return"]=df["close"].pct_change()
df
# Out:
#                           date       open       high        low      close  \
# 0    2015-05-21 04:00:00+00:00   2.800000   2.874000   2.411000   2.568000
# 1    2015-05-22 04:00:00+00:00   2.607000   3.110000   2.600000   2.831000
# 2    2015-05-26 04:00:00+00:00   2.980000   3.034000   2.908000   2.965000
# 3    2015-05-27 04:00:00+00:00   3.067000   3.081000   2.700000   2.750000
# 4    2015-05-28 04:00:00+00:00   2.755000   2.774000   2.648000   2.745000
# ...                        ...        ...        ...        ...        ...
# 2464 2025-03-10 04:00:00+00:00  96.070000  96.186996  91.690002  92.750000
# 2465 2025-03-11 04:00:00+00:00  92.750000  95.109001  91.150002  92.949997
# 2466 2025-03-12 04:00:00+00:00  96.669998  99.135002  95.290001  96.529999
# 2467 2025-03-13 04:00:00+00:00  95.169998  95.529999  89.099998  90.589996
# 2468 2025-03-14 04:00:00+00:00  94.610001  95.830002  93.059998  94.849998
#
#       adj_close     volume        MA20      MA50  Daily_Return
# 0      2.568000  123039000         NaN       NaN           NaN
# 1      2.831000   28412000         NaN       NaN      0.102414
# 2      2.965000    8202000         NaN       NaN      0.047333
# 3      2.750000    7976000         NaN       NaN     -0.072513
# 4      2.745000    4000000         NaN       NaN     -0.001818
# ...         ...        ...         ...       ...           ...
# 2464  92.750000   16385300  114.415001  111.7678     -0.073704
# 2465  92.949997   12127100  113.067500  111.4232      0.002156
# 2466  96.529999    8531900  111.714500  111.1546      0.038515
# 2467  90.589996   11076400  110.219500  110.8028     -0.061535
# 2468  94.849998    7060700  108.579500  110.5660      0.047025
#
# [2469 rows x 10 columns]

# %%
plt.figure(figsize=(10,6))
sns.histplot(
    df["Daily_Return"].dropna(),
    bins=50,
    kde=True
)
plt.title("Shopify Daily Returns")
plt.xlabel("Daily Return")
plt.ylabel("Frequency")
plt.show()
